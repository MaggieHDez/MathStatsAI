# %% [markdown]
# <a href="https://colab.research.google.com/github/MaggieHDez/MathStatsAI/blob/main/conceptos_estadisticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aplicaciones de conceptos estadísticos en conjunto de datos**
# >**Alumno:** Margarita Cristina Hernández Delgadillo\
# >**Matrícula:** 255879

# %% [markdown]
# ##**1. Operaciones básicas**
# **Objetivo:** Crear y manipular arrays.\
# **Instrucciones:**
# 1. Crea un array de 10 elementos con valores entre 1 y 10.
# 2. Calcula la media, mediana, y desviación estándar de los valores.
# 3. Multiplica cada valor por 2.

# %% [markdown]
# ### **Código y Resultados**

# %%
# Creacion del array
import numpy as np

arr = np.random.randint(0, 11, 10)
print('arreglo: ', arr)

# Media
media = arr.mean()
print('media: ', media)

# mediana
mediana = np.median(arr)
print('mediana: ', mediana)

# Desviación estándar
desviacion = np.std(arr)
print(f"desviación estándar: {desviacion:.2f}")

# Multiplicación de los valores del arreglo * 2
arr_multiplicado = arr * 2
print('arreglo multiplicado: ', arr_multiplicado)
# Out:
# arreglo:  [ 2  7  5  5  3  9  1  8 10  1]
# media:  5.1
# mediana:  5.0
# desviación estándar: 3.14
# arreglo multiplicado:  [ 4 14 10 10  6 18  2 16 20  2]

# %% [markdown]
# ##**2. Operaciones con DataFrames**
# **Objetivo:** Crear y manipular un DataFrame.\
# **Instrucciones:**
# 1. Crea un DataFrame con 3 columnas (A, B, C) y 5 filas con números aleatorios enteros.
# 2. Renombra las columnas a Col1, Col2, Col3.
# 3. Añade una nueva columna que sea la suma de las columnas Col1 y Col2.
# 4. Elimina todas las filas donde el valor de Col3 sea menor que 10.

# %% [markdown]
# ### **Código y Resultados**

# %%
# Creación del DataFrame
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(0, 101, size=(5, 3))) # size=5 filas, 3 columnas
print(df,'\n')

# Renombrar las columnas
df = df.rename(columns={0: 'Col1', 1: 'Col2', 2: 'Col3'})
print('Columnas renombadas\n', df,'\n')

# Nueva columna
df['Col4'] = df['Col1'] + df['Col2']
print('Nueva columna\n', df,'\n')

# Eliminar filas
df = df[df['Col3'] >= 10]
print('Columnas después de la eliminación\n', df)
# Out:
#     0   1   2
# 0  54  80  54
# 1  48  51   7
# 2  51  63  64
# 3  88  53  49
# 4  75  47  16
#
# Columnas renombadas
#     Col1  Col2  Col3
# 0    54    80    54
# 1    48    51     7
# 2    51    63    64
# 3    88    53    49
# 4    75    47    16
#
# Nueva columna
#     Col1  Col2  Col3  Col4
# 0    54    80    54   134
# 1    48    51     7    99
# 2    51    63    64   114
# 3    88    53    49   141
# 4    75    47    16   122
#
# Columnas después de la eliminación
#     Col1  Col2  Col3  Col4
# 0    54    80    54   134
# 2    51    63    64   114
# 3    88    53    49   141
# 4    75    47    16   122

# %% [markdown]
# ##**3. Estadística descriptiva**
# **Objetivo:** Aplicar análisis estadístico básico.\
# **Instrucciones:**
# 1. Crea un DataFrame con 100 valores aleatorios entre 0 y 50.
# 2. Calcula la media, mediana y moda de los valores.
# 3. Encuentra el valor mínimo y el valor máximo del DataFrame.

# %% [markdown]
# ### **Código y Resultados**

# %%
import pandas as pd
import numpy as np

# Creación de DataFrame
df = pd.DataFrame(np.random.randint(0, 51, size=(100, 1)))
print('DataFrame\n', df,'\n')

# Media
media = np.mean(df)
print('media: ', media)

# Mediana
mediana = np.median(df)
print('mediana: ', mediana)

# Moda
moda = df.mode()
print('moda: ', moda[0].to_string(index=False))

# Valor mínimo
minimo = np.min(df)
print('valor mínimo: ', minimo)

# Valor máximo
maximo = np.max(df)
print('valor máximo: ', maximo)
# Out:
# DataFrame
#       0
# 0   34
# 1   22
# 2   43
# 3    0
# 4   22
# ..  ..
# 95  25
# 96  50
# 97  30
# 98  26
# 99  41
#
# [100 rows x 1 columns]
#
# media:  25.36
# mediana:  25.0
# moda:  50
# valor mínimo:  0
# valor máximo:  50

# %% [markdown]
# ##**4. Análisis de series temporales**
# **Objetivo:** Trabajar con fechas y series temporales.\
# **Instrucciones:**
# 1. Crea un DataFrame con una columna de fechas (usa pd.date_range() para generar las fechas).
# 2. Genera 100 valores aleatorios asociados a estas fechas.
# 3. Calcula la media móvil de los valores con una ventana de 5 días.

# %% [markdown]
# ### **Código y Resultados**

# %%
import pandas as pd
import numpy as np

# Creación de DataFrame
df = pd.DataFrame(pd.date_range(start='2023-01-01', periods=100, freq='D'))

# Valores aleatorios
df['valores'] = np.random.randint(0, 101, size=(100, 1))

# Media móvil
df['media_movil'] = df['valores'].rolling(window=5).mean()
print(df)
# Out:
#             0  valores  media_movil
# 0  2023-01-01       22          NaN
# 1  2023-01-02       96          NaN
# 2  2023-01-03       59          NaN
# 3  2023-01-04       27          NaN
# 4  2023-01-05       38         48.4
# ..        ...      ...          ...
# 95 2023-04-06        5         51.8
# 96 2023-04-07       51         53.0
# 97 2023-04-08       43         50.0
# 98 2023-04-09       12         40.0
# 99 2023-04-10       93         40.8
#
# [100 rows x 3 columns]

# %% [markdown]
# ##**5. Gráfico de Líneas**
# **Objetivo:** Visualizar la tendencia de una serie de datos.\
# **Instrucciones:**
# - Crea una serie de datos aleatorios (entre 0 y 100) de tamaño 50.
# - Usa Matplotlib para graficar los datos en un gráfico de líneas.
# - Añade título, etiquetas a los ejes y una leyenda.
# - Cambia el color de la línea a rojo y usa un estilo de línea punteado.

# %% [markdown]
# ### **Código y Resultados**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos aleatorios entre 0 y 100 de tamaño 50
datos = np.random.randint(0, 101, size=(50))

# Gráfico de líneas
plt.figure(figsize=(10, 6))
plt.plot(datos, color='green', linestyle='--', label='Datos')
plt.title('Gráfico de líneas de datos aleatorios (0-100)')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend()
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ##**6. Gráfico de Barras**
# **Objetivo:** Visualizar datos categóricos.\
# **Instrucciones:**
# 1. Carga el dataset tips de Seaborn.
# 2. Realiza un gráfico de barras que muestre el total de las cuentas (total_bill)
# agrupadas por día.
# 3. Añade etiquetas a los ejes y un título.

# %% [markdown]
# ### **Código y Resultados**

# %%
# Cargar biblioteca seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el dataset tips de Seaborn
tips = sns.load_dataset('tips')

# Gráfico de barras
ax = sns.barplot(x='day', y='total_bill', data=tips, hue='day', errorbar=None)
for p in ax.patches:
    height = p.get_height()
    ax.text(
        p.get_x() + p.get_width() / 2,   # posición X: centro de la barra
        height + 1,                      # posición Y: un poquito arriba de la barra
        f'{float(height):.2f}',          # texto: total decimal
        ha='center',
        va='top'
    )
plt.title('Total de cuentas agrupadas por día')
plt.xlabel('Día')
plt.ylabel('Total de cuentas')
plt.show()

# %% [markdown]
# ##**7. Histograma**
# **Objetivo:** Visualizar la distribución de datos numéricos.\
# **Instrucciones:**
# 1. Genera 1000 números aleatorios con distribución normal (media = 0, desviación estándar = 1).
# 2. Crea un histograma para visualizar la distribución.
# 3. Ajusta el número de bins del histograma para que la visualización sea clara.

# %% [markdown]
# ### **Código y Resultados**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Números aleatorios
datos = np.random.normal(0, 1, 1000)

# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(datos, bins=30, kde=True, color='maroon')
plt.title('Histograma de distribución normal')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ##**8. Scatter Plot**
# **Objetivo:** Visualizar la relación entre dos variables.\
# **Instrucciones:**
# 1. Usa el dataset iris de Seaborn.
# 2. Crea un gráfico de dispersión (scatter plot) para visualizar la relación entre el ancho del sépalo (sepal_width) y la longitud del sépalo (sepal_length).
# 3. Añade colores diferentes según la especie de flor.

# %% [markdown]
# ### **Código y Resultados**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargando Dataset
iris = sns.load_dataset('iris')

# Gráfico
plt.figure(figsize=(10, 6))
sns.scatterplot(data=iris, x='sepal_width', y='sepal_length', hue='species')
plt.title('Relación entre ancho del sépalo y longitud del sépalo')
plt.xlabel('Ancho del sépalo')
plt.ylabel('Longitud del sépalo')
plt.legend(title='Especie')
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ##**9. Heatmap**
# **Objetivo:** Visualizar la correlación entre variables numéricas.\
# **Instrucciones:**
# 1. Usa el dataset iris de Seaborn.
# 2. Calcula la matriz de correlación de las variables.
# 3. Crea un heatmap para visualizar la matriz de correlación.

# %% [markdown]
# ### **Código y Resultados**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargando Dataset
iris = sns.load_dataset('iris')

# Solo las variables numéricas
iris_num = iris.select_dtypes(include=['float64', 'int64'])

# Matriz dew correlación
matriz_corr = iris_num.corr()

# Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de correlación entre variables numéricas')
plt.show()

# %% [markdown]
# ##**10. Gráfico de Línea con Media Móvil**
# **Objetivo:** Visualizar series temporales.\
# **Instrucciones:**
# 1. Genera una serie temporal de 100 días con valores aleatorios.
# 2. Calcula la media móvil de los últimos 10 días y grafícala junto a la serie original.
# 3. Usa diferentes colores para la serie original y la media móvil.

# %% [markdown]
# ### **Código y Resultados**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creación de días
dias = pd.date_range(start='2024-01-01', periods=100, freq='D')

# Serie
np.random.seed(1)
valores = np.random.randn(100).cumsum() # Serie aleatoria acumulada para más variación
serie = pd.Series(valores, index=dias)

# Media móvil
media_movil = serie.rolling(window=10).mean()

# Gráfica
plt.figure(figsize=(10, 6))
plt.plot(serie.index, serie, label='Serie Original', color='blue')
plt.plot(media_movil.index, media_movil, label='Media móvil (últimos 10 días)', color='red')
plt.title('Serie temporal con media móvil')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()
plt.tight_layout()
plt.grid(True, linestyle='--')
plt.show()

# %% [markdown]
# ##**11. Datos Temporales con Análisis Estadístico**
# **Objetivo:** Trabajar con series temporales y calcular estadísticas.\
# **Instrucciones:**
# 1. Genera una serie temporal de 200 días con valores aleatorios.
# 2. Calcula la media y la desviación estándar de la serie temporal.
# 3. Visualiza la serie junto con las bandas de desviación estándar (es decir, la media ± 1 desviación estándar).

# %% [markdown]
# ### **Código y Resultados**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creación de días
dias = pd.date_range(start='2024-01-01', periods=200, freq='D')

# Valores
np.random.seed(2)
valores = np.random.randn(200)
serie = pd.Series(valores, index=dias)

# Media y desviación estándar
media = serie.mean()
desviacion_estandar = serie.std()

print(f'media: {media:.4f}')
print(f'desviación estándar: {desviacion_estandar:.4f}')

# Bandas de desviación estándar
banda_superior = media + desviacion_estandar
banda_inferior = media - desviacion_estandar

# Gráfica
plt.figure(figsize=(12, 6))
plt.fill_between(serie.index, banda_inferior, banda_superior, alpha=0.2,
                 label='Media ± 1 desviación estándar', color='blue')
plt.plot(serie.index, serie, label='Serie Temporal', color='maroon')
plt.axhline(media, linestyle='--', label='Media', color='navy')
plt.title('Serie Temporal con Bandas de Desviación Estándar')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# media: 0.0123
# desviación estándar: 1.0828

# %% [markdown]
# ### **Enlace de Github**
# https://github.com/MaggieHDez/MathStatsAI/blob/main/conceptos_estadisticos.ipynb
